# %%
import tensorflow as tf
import numpy as np

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/",one_hot = True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
learning_rate = .01
max_examples = 400000
batch_size = 128
display_step = 10

# %%
n_input = 28
n_steps = 28
n_hidden = 256
n_classes = 10

# %%
x = tf.placeholder("float",[None, n_steps, n_input])
y = tf.placeholder("float",[None, n_classes])

weights = tf.Variable(tf.random_normal([2*n_hidden, n_classes]))
biases = tf.Variable(tf.random_normal([n_classes]))

# %%
def BiRNN(x,weights,biases):
    x = tf.transpose(x,[1,0,2])
    x = tf.reshape(x,[-1,n_input])
    x = tf.split(x,n_steps)
    
    lstm_fw_cell = tf.contrib.rnn.BasicLSTMCell(n_hidden, forget_bias=1.0)
    lstm_bw_cell = tf.contrib.rnn.BasicLSTMCell(n_hidden, forget_bias=1.0)
    
    outputs,__,_ = tf.contrib.rnn.static_bidirectional_rnn(lstm_fw_cell,lstm_bw_cell,x,dtype=tf.float32)
    return tf.matmul(outputs[-1],weights)+biases

# %%
pred = BiRNN(x,weights,biases)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = pred, labels = y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)
correct_pred = tf.equal(tf.argmax(pred,1),tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred,tf.float32))
init = tf.global_variables_initializer()

# %%
with tf.Session() as sess:
    sess.run(init)
    step = 1
    while step*batch_size < max_examples:
        batch_x,batch_y = mnist.train.next_batch(batch_size)
        batch_x = batch_x.reshape((batch_size,n_steps,n_input))
        sess.run(optimizer, feed_dict = {x: batch_x, y: batch_y})
        if step%display_step == 0:
            acc = sess.run(accuracy, feed_dict = {x: batch_x, y: batch_y})
            loss = sess.run(cost, feed_dict = {x: batch_x, y: batch_y})
            print("Iter "+str(step*batch_size)+",Minibatch Loss = " + \
                 "{:.6f}".format(loss) + ", Training Accuracy = " + \
                 "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished")
# Out:
# Iter 1280,Minibatch Loss = 1.770682, Training Accuracy = 0.40625
# Iter 2560,Minibatch Loss = 1.127459, Training Accuracy = 0.56250
# Iter 3840,Minibatch Loss = 0.959938, Training Accuracy = 0.66406
# Iter 5120,Minibatch Loss = 0.818625, Training Accuracy = 0.74219
# Iter 6400,Minibatch Loss = 0.708665, Training Accuracy = 0.74219
# Iter 7680,Minibatch Loss = 0.654192, Training Accuracy = 0.76562
# Iter 8960,Minibatch Loss = 0.414732, Training Accuracy = 0.86719
# Iter 10240,Minibatch Loss = 0.470856, Training Accuracy = 0.84375
# Iter 11520,Minibatch Loss = 0.339409, Training Accuracy = 0.89844
# Iter 12800,Minibatch Loss = 0.513396, Training Accuracy = 0.82812
# Iter 14080,Minibatch Loss = 0.279302, Training Accuracy = 0.89062
# Iter 15360,Minibatch Loss = 0.197083, Training Accuracy = 0.92188
# Iter 16640,Minibatch Loss = 0.171364, Training Accuracy = 0.94531
# Iter 17920,Minibatch Loss = 0.257465, Training Accuracy = 0.92969
# Iter 19200,Minibatch Loss = 0.219626, Training Accuracy = 0.93750
# Iter 20480,Minibatch Loss = 0.080279, Training Accuracy = 0.99219
# Iter 21760,Minibatch Loss = 0.350160, Training Accuracy = 0.89844
# Iter 23040,Minibatch Loss = 0.173637, Training Accuracy = 0.94531
# Iter 24320,Minibatch Loss = 0.304497, Training Accuracy = 0.91406
# Iter 25600,Minibatch Loss = 0.266652, Training Accuracy = 0.92188
# Iter 26880,Minibatch Loss = 0.134510, Training Accuracy = 0.95312
# Iter 28160,Minibatch Loss = 0.195708, Training Accuracy = 0.93750
# Iter 29440,Minibatch Loss = 0.265738, Training Accuracy = 0.94531
# Iter 30720,Minibatch Loss = 0.185852, Training Accuracy = 0.96094
# Iter 32000,Minibatch Loss = 0.137413, Training Accuracy = 0.96094
# Iter 33280,Minibatch Loss = 0.092539, Training Accuracy = 0.98438
# Iter 34560,Minibatch Loss = 0.142208, Training Accuracy = 0.95312
# Iter 35840,Minibatch Loss = 0.122681, Training Accuracy = 0.96094
# Iter 37120,Minibatch Loss = 0.120700, Training Accuracy = 0.95312
# Iter 38400,Minibatch Loss = 0.101476, Training Accuracy = 0.97656
# Iter 39680,Minibatch Loss = 0.045669, Training Accuracy = 0.99219
# Iter 40960,Minibatch Loss = 0.153141, Training Accuracy = 0.96875
# Iter 42240,Minibatch Loss = 0.119809, Training Accuracy = 0.96875
# Iter 43520,Minibatch Loss = 0.116051, Training Accuracy = 0.97656
# Iter 44800,Minibatch Loss = 0.089178, Training Accuracy = 0.97656
# Iter 46080,Minibatch Loss = 0.057272, Training Accuracy = 0.97656
# Iter 47360,Minibatch Loss = 0.087969, Training Accuracy = 0.96094
# Iter 48640,Minibatch Loss = 0.148127, Training Accuracy = 0.96094
# Iter 49920,Minibatch Loss = 0.092606, Training Accuracy = 0.96875
# Iter 51200,Minibatch Loss = 0.045238, Training Accuracy = 0.98438
# Iter 52480,Minibatch Loss = 0.100006, Training Accuracy = 0.97656
# Iter 53760,Minibatch Loss = 0.043174, Training Accuracy = 0.97656
# Iter 55040,Minibatch Loss = 0.123790, Training Accuracy = 0.96094
# Iter 56320,Minibatch Loss = 0.041090, Training Accuracy = 0.99219
# Iter 57600,Minibatch Loss = 0.091777, Training Accuracy = 0.96875
# Iter 58880,Minibatch Loss = 0.029963, Training Accuracy = 0.98438
# Iter 60160,Minibatch Loss = 0.088073, Training Accuracy = 0.96875
# Iter 61440,Minibatch Loss = 0.131966, Training Accuracy = 0.96094
# Iter 62720,Minibatch Loss = 0.036840, Training Accuracy = 0.99219
# Iter 64000,Minibatch Loss = 0.023229, Training Accuracy = 0.99219
# Iter 65280,Minibatch Loss = 0.104991, Training Accuracy = 0.97656
# Iter 66560,Minibatch Loss = 0.036249, Training Accuracy = 0.98438
# Iter 67840,Minibatch Loss = 0.071385, Training Accuracy = 0.97656
# Iter 69120,Minibatch Loss = 0.055715, Training Accuracy = 0.98438
# Iter 70400,Minibatch Loss = 0.047212, Training Accuracy = 0.98438
# Iter 71680,Minibatch Loss = 0.177576, Training Accuracy = 0.96094
# Iter 72960,Minibatch Loss = 0.092720, Training Accuracy = 0.96875
# Iter 74240,Minibatch Loss = 0.056390, Training Accuracy = 0.98438
# Iter 75520,Minibatch Loss = 0.071573, Training Accuracy = 0.98438
# Iter 76800,Minibatch Loss = 0.062820, Training Accuracy = 0.97656
# Iter 78080,Minibatch Loss = 0.086843, Training Accuracy = 0.96094
# Iter 79360,Minibatch Loss = 0.069453, Training Accuracy = 0.97656
# Iter 80640,Minibatch Loss = 0.058944, Training Accuracy = 0.97656
# Iter 81920,Minibatch Loss = 0.138584, Training Accuracy = 0.92188
# Iter 83200,Minibatch Loss = 0.058434, Training Accuracy = 0.98438
# Iter 84480,Minibatch Loss = 0.094534, Training Accuracy = 0.97656
# Iter 85760,Minibatch Loss = 0.089285, Training Accuracy = 0.97656
# Iter 87040,Minibatch Loss = 0.057959, Training Accuracy = 0.98438
# Iter 88320,Minibatch Loss = 0.042762, Training Accuracy = 0.99219
# Iter 89600,Minibatch Loss = 0.079104, Training Accuracy = 0.98438
# Iter 90880,Minibatch Loss = 0.024499, Training Accuracy = 0.99219
# Iter 92160,Minibatch Loss = 0.022327, Training Accuracy = 1.00000
# Iter 93440,Minibatch Loss = 0.046194, Training Accuracy = 0.98438
# Iter 94720,Minibatch Loss = 0.058530, Training Accuracy = 0.98438
# Iter 96000,Minibatch Loss = 0.035969, Training Accuracy = 0.99219
# Iter 97280,Minibatch Loss = 0.031562, Training Accuracy = 0.99219
# Iter 98560,Minibatch Loss = 0.052918, Training Accuracy = 0.98438
# Iter 99840,Minibatch Loss = 0.050997, Training Accuracy = 0.98438
# Iter 101120,Minibatch Loss = 0.088901, Training Accuracy = 0.96875
# Iter 102400,Minibatch Loss = 0.020659, Training Accuracy = 0.99219
# Iter 103680,Minibatch Loss = 0.102983, Training Accuracy = 0.97656
# Iter 104960,Minibatch Loss = 0.042077, Training Accuracy = 0.98438
# Iter 106240,Minibatch Loss = 0.041039, Training Accuracy = 0.98438
# Iter 107520,Minibatch Loss = 0.080252, Training Accuracy = 0.99219
# Iter 108800,Minibatch Loss = 0.023632, Training Accuracy = 1.00000
# Iter 110080,Minibatch Loss = 0.063366, Training Accuracy = 0.97656
# Iter 111360,Minibatch Loss = 0.010736, Training Accuracy = 1.00000
# Iter 112640,Minibatch Loss = 0.061819, Training Accuracy = 0.97656
# Iter 113920,Minibatch Loss = 0.029034, Training Accuracy = 0.98438
# Iter 115200,Minibatch Loss = 0.023866, Training Accuracy = 0.99219
# Iter 116480,Minibatch Loss = 0.009714, Training Accuracy = 1.00000
# Iter 117760,Minibatch Loss = 0.036570, Training Accuracy = 0.97656
# Iter 119040,Minibatch Loss = 0.087459, Training Accuracy = 0.98438
# Iter 120320,Minibatch Loss = 0.029852, Training Accuracy = 0.98438
# Iter 121600,Minibatch Loss = 0.037977, Training Accuracy = 0.99219
# Iter 122880,Minibatch Loss = 0.124601, Training Accuracy = 0.97656
# Iter 124160,Minibatch Loss = 0.042014, Training Accuracy = 0.99219
# Iter 125440,Minibatch Loss = 0.050409, Training Accuracy = 0.99219
# Iter 126720,Minibatch Loss = 0.083523, Training Accuracy = 0.97656
# Iter 128000,Minibatch Loss = 0.090160, Training Accuracy = 0.97656
# Iter 129280,Minibatch Loss = 0.017613, Training Accuracy = 1.00000
# Iter 130560,Minibatch Loss = 0.060515, Training Accuracy = 0.97656
# Iter 131840,Minibatch Loss = 0.046218, Training Accuracy = 0.99219
# Iter 133120,Minibatch Loss = 0.098619, Training Accuracy = 0.98438
# Iter 134400,Minibatch Loss = 0.011406, Training Accuracy = 1.00000
# Iter 135680,Minibatch Loss = 0.053184, Training Accuracy = 0.98438
# Iter 136960,Minibatch Loss = 0.057402, Training Accuracy = 0.98438
# Iter 138240,Minibatch Loss = 0.070983, Training Accuracy = 0.98438
# Iter 139520,Minibatch Loss = 0.029501, Training Accuracy = 0.99219
# Iter 140800,Minibatch Loss = 0.053201, Training Accuracy = 0.97656
# Iter 142080,Minibatch Loss = 0.044171, Training Accuracy = 0.99219
# Iter 143360,Minibatch Loss = 0.024706, Training Accuracy = 0.99219
# Iter 144640,Minibatch Loss = 0.022986, Training Accuracy = 1.00000
# Iter 145920,Minibatch Loss = 0.039492, Training Accuracy = 0.97656
# Iter 147200,Minibatch Loss = 0.025446, Training Accuracy = 0.99219
# Iter 148480,Minibatch Loss = 0.054116, Training Accuracy = 0.98438
# Iter 149760,Minibatch Loss = 0.032434, Training Accuracy = 0.98438
# Iter 151040,Minibatch Loss = 0.035651, Training Accuracy = 0.99219
# Iter 152320,Minibatch Loss = 0.022985, Training Accuracy = 0.99219
# Iter 153600,Minibatch Loss = 0.015377, Training Accuracy = 1.00000
# Iter 154880,Minibatch Loss = 0.046736, Training Accuracy = 0.97656
# Iter 156160,Minibatch Loss = 0.061782, Training Accuracy = 0.99219
# Iter 157440,Minibatch Loss = 0.088594, Training Accuracy = 0.98438
# Iter 158720,Minibatch Loss = 0.017819, Training Accuracy = 1.00000
# Iter 160000,Minibatch Loss = 0.011139, Training Accuracy = 1.00000
# Iter 161280,Minibatch Loss = 0.017250, Training Accuracy = 0.99219
# Iter 162560,Minibatch Loss = 0.031790, Training Accuracy = 0.98438
# Iter 163840,Minibatch Loss = 0.036069, Training Accuracy = 0.99219
# Iter 165120,Minibatch Loss = 0.011986, Training Accuracy = 1.00000
# Iter 166400,Minibatch Loss = 0.003453, Training Accuracy = 1.00000
# Iter 167680,Minibatch Loss = 0.004794, Training Accuracy = 1.00000
# Iter 168960,Minibatch Loss = 0.072042, Training Accuracy = 0.98438
# Iter 170240,Minibatch Loss = 0.031395, Training Accuracy = 0.99219
# Iter 171520,Minibatch Loss = 0.039396, Training Accuracy = 0.97656
# Iter 172800,Minibatch Loss = 0.088274, Training Accuracy = 0.99219
# Iter 174080,Minibatch Loss = 0.015560, Training Accuracy = 1.00000
# Iter 175360,Minibatch Loss = 0.015123, Training Accuracy = 1.00000
# Iter 176640,Minibatch Loss = 0.015512, Training Accuracy = 1.00000
# Iter 177920,Minibatch Loss = 0.043939, Training Accuracy = 0.98438
# Iter 179200,Minibatch Loss = 0.017327, Training Accuracy = 1.00000
# Iter 180480,Minibatch Loss = 0.006047, Training Accuracy = 1.00000
# Iter 181760,Minibatch Loss = 0.031746, Training Accuracy = 0.99219
# Iter 183040,Minibatch Loss = 0.048724, Training Accuracy = 0.97656
# Iter 184320,Minibatch Loss = 0.069628, Training Accuracy = 0.99219
# Iter 185600,Minibatch Loss = 0.037270, Training Accuracy = 0.99219
# Iter 186880,Minibatch Loss = 0.074033, Training Accuracy = 0.96875
# Iter 188160,Minibatch Loss = 0.014497, Training Accuracy = 1.00000
# Iter 189440,Minibatch Loss = 0.037641, Training Accuracy = 0.98438
# Iter 190720,Minibatch Loss = 0.044490, Training Accuracy = 0.99219
# Iter 192000,Minibatch Loss = 0.023064, Training Accuracy = 0.98438
# Iter 193280,Minibatch Loss = 0.060875, Training Accuracy = 0.96875
# Iter 194560,Minibatch Loss = 0.114803, Training Accuracy = 0.98438
# Iter 195840,Minibatch Loss = 0.026030, Training Accuracy = 0.99219
# Iter 197120,Minibatch Loss = 0.038944, Training Accuracy = 0.99219
# Iter 198400,Minibatch Loss = 0.007673, Training Accuracy = 1.00000
# Iter 199680,Minibatch Loss = 0.006708, Training Accuracy = 1.00000
# Iter 200960,Minibatch Loss = 0.068916, Training Accuracy = 0.97656
# Iter 202240,Minibatch Loss = 0.021968, Training Accuracy = 0.99219
# Iter 203520,Minibatch Loss = 0.030880, Training Accuracy = 0.99219
# Iter 204800,Minibatch Loss = 0.032191, Training Accuracy = 0.99219
# Iter 206080,Minibatch Loss = 0.066694, Training Accuracy = 0.97656
# Iter 207360,Minibatch Loss = 0.006295, Training Accuracy = 1.00000
# Iter 208640,Minibatch Loss = 0.078074, Training Accuracy = 0.96875
# Iter 209920,Minibatch Loss = 0.027156, Training Accuracy = 0.99219
# Iter 211200,Minibatch Loss = 0.023349, Training Accuracy = 1.00000
# Iter 212480,Minibatch Loss = 0.023567, Training Accuracy = 0.99219
# Iter 213760,Minibatch Loss = 0.014055, Training Accuracy = 1.00000
# Iter 215040,Minibatch Loss = 0.025009, Training Accuracy = 0.99219
# Iter 216320,Minibatch Loss = 0.012078, Training Accuracy = 1.00000
# Iter 217600,Minibatch Loss = 0.018429, Training Accuracy = 0.99219
# Iter 218880,Minibatch Loss = 0.078811, Training Accuracy = 0.98438
# Iter 220160,Minibatch Loss = 0.015379, Training Accuracy = 1.00000
# Iter 221440,Minibatch Loss = 0.029734, Training Accuracy = 0.99219
# Iter 222720,Minibatch Loss = 0.022024, Training Accuracy = 1.00000
# Iter 224000,Minibatch Loss = 0.033546, Training Accuracy = 0.99219
# Iter 225280,Minibatch Loss = 0.011910, Training Accuracy = 1.00000
# Iter 226560,Minibatch Loss = 0.033652, Training Accuracy = 0.99219
# Iter 227840,Minibatch Loss = 0.089092, Training Accuracy = 0.97656
# Iter 229120,Minibatch Loss = 0.023457, Training Accuracy = 0.99219
# Iter 230400,Minibatch Loss = 0.011584, Training Accuracy = 1.00000
# Iter 231680,Minibatch Loss = 0.002601, Training Accuracy = 1.00000
# Iter 232960,Minibatch Loss = 0.043567, Training Accuracy = 0.98438
# Iter 234240,Minibatch Loss = 0.101951, Training Accuracy = 0.98438
# Iter 235520,Minibatch Loss = 0.092183, Training Accuracy = 0.97656
# Iter 236800,Minibatch Loss = 0.023292, Training Accuracy = 0.99219
# Iter 238080,Minibatch Loss = 0.037475, Training Accuracy = 0.99219
# Iter 239360,Minibatch Loss = 0.009632, Training Accuracy = 1.00000
# Iter 240640,Minibatch Loss = 0.007169, Training Accuracy = 1.00000
# Iter 241920,Minibatch Loss = 0.006552, Training Accuracy = 1.00000
# Iter 243200,Minibatch Loss = 0.013738, Training Accuracy = 0.99219
# Iter 244480,Minibatch Loss = 0.028608, Training Accuracy = 0.99219
# Iter 245760,Minibatch Loss = 0.004710, Training Accuracy = 1.00000
# Iter 247040,Minibatch Loss = 0.006254, Training Accuracy = 1.00000
# Iter 248320,Minibatch Loss = 0.008602, Training Accuracy = 1.00000
# Iter 249600,Minibatch Loss = 0.023471, Training Accuracy = 1.00000
# Iter 250880,Minibatch Loss = 0.035670, Training Accuracy = 0.98438
# Iter 252160,Minibatch Loss = 0.039948, Training Accuracy = 0.97656
# Iter 253440,Minibatch Loss = 0.025072, Training Accuracy = 0.99219
# Iter 254720,Minibatch Loss = 0.009429, Training Accuracy = 1.00000
# Iter 256000,Minibatch Loss = 0.012056, Training Accuracy = 1.00000
# Iter 257280,Minibatch Loss = 0.016706, Training Accuracy = 0.99219
# Iter 258560,Minibatch Loss = 0.077756, Training Accuracy = 0.99219
# Iter 259840,Minibatch Loss = 0.020077, Training Accuracy = 0.99219
# Iter 261120,Minibatch Loss = 0.051348, Training Accuracy = 0.99219
# Iter 262400,Minibatch Loss = 0.037721, Training Accuracy = 0.99219
# Iter 263680,Minibatch Loss = 0.020322, Training Accuracy = 0.99219
# Iter 264960,Minibatch Loss = 0.019954, Training Accuracy = 0.99219
# Iter 266240,Minibatch Loss = 0.026454, Training Accuracy = 1.00000
# Iter 267520,Minibatch Loss = 0.055085, Training Accuracy = 0.98438
# Iter 268800,Minibatch Loss = 0.032302, Training Accuracy = 0.99219
# Iter 270080,Minibatch Loss = 0.056976, Training Accuracy = 0.99219
# Iter 271360,Minibatch Loss = 0.037823, Training Accuracy = 0.98438
# Iter 272640,Minibatch Loss = 0.009811, Training Accuracy = 1.00000
# Iter 273920,Minibatch Loss = 0.007898, Training Accuracy = 1.00000
# Iter 275200,Minibatch Loss = 0.013452, Training Accuracy = 1.00000
# Iter 276480,Minibatch Loss = 0.005361, Training Accuracy = 1.00000
# Iter 277760,Minibatch Loss = 0.042979, Training Accuracy = 0.98438
# Iter 279040,Minibatch Loss = 0.013670, Training Accuracy = 0.99219
# Iter 280320,Minibatch Loss = 0.022632, Training Accuracy = 0.99219
# Iter 281600,Minibatch Loss = 0.018020, Training Accuracy = 0.99219
# Iter 282880,Minibatch Loss = 0.021664, Training Accuracy = 0.99219
# Iter 284160,Minibatch Loss = 0.015260, Training Accuracy = 1.00000
# Iter 285440,Minibatch Loss = 0.015335, Training Accuracy = 1.00000
# Iter 286720,Minibatch Loss = 0.025340, Training Accuracy = 0.98438
# Iter 288000,Minibatch Loss = 0.034746, Training Accuracy = 0.99219
# Iter 289280,Minibatch Loss = 0.026426, Training Accuracy = 1.00000
# Iter 290560,Minibatch Loss = 0.027158, Training Accuracy = 0.99219
# Iter 291840,Minibatch Loss = 0.016904, Training Accuracy = 0.99219
# Iter 293120,Minibatch Loss = 0.004616, Training Accuracy = 1.00000
# Iter 294400,Minibatch Loss = 0.006336, Training Accuracy = 1.00000
# Iter 295680,Minibatch Loss = 0.037376, Training Accuracy = 0.99219
# Iter 296960,Minibatch Loss = 0.020786, Training Accuracy = 1.00000
# Iter 298240,Minibatch Loss = 0.020688, Training Accuracy = 0.99219
# Iter 299520,Minibatch Loss = 0.006459, Training Accuracy = 1.00000
# Iter 300800,Minibatch Loss = 0.012604, Training Accuracy = 1.00000
# Iter 302080,Minibatch Loss = 0.022370, Training Accuracy = 0.99219
# Iter 303360,Minibatch Loss = 0.007866, Training Accuracy = 1.00000
# Iter 304640,Minibatch Loss = 0.054337, Training Accuracy = 0.98438
# Iter 305920,Minibatch Loss = 0.025973, Training Accuracy = 0.99219
# Iter 307200,Minibatch Loss = 0.077660, Training Accuracy = 0.96875
# Iter 308480,Minibatch Loss = 0.011139, Training Accuracy = 0.99219
# Iter 309760,Minibatch Loss = 0.024095, Training Accuracy = 0.99219
# Iter 311040,Minibatch Loss = 0.003257, Training Accuracy = 1.00000
# Iter 312320,Minibatch Loss = 0.006642, Training Accuracy = 1.00000
# Iter 313600,Minibatch Loss = 0.005733, Training Accuracy = 1.00000
# Iter 314880,Minibatch Loss = 0.006204, Training Accuracy = 1.00000
# Iter 316160,Minibatch Loss = 0.077030, Training Accuracy = 0.97656
# Iter 317440,Minibatch Loss = 0.004587, Training Accuracy = 1.00000
# Iter 318720,Minibatch Loss = 0.013331, Training Accuracy = 0.99219
# Iter 320000,Minibatch Loss = 0.081995, Training Accuracy = 0.99219
# Iter 321280,Minibatch Loss = 0.007234, Training Accuracy = 1.00000
# Iter 322560,Minibatch Loss = 0.026405, Training Accuracy = 0.98438
# Iter 323840,Minibatch Loss = 0.035614, Training Accuracy = 0.99219
# Iter 325120,Minibatch Loss = 0.014284, Training Accuracy = 0.99219
# Iter 326400,Minibatch Loss = 0.012706, Training Accuracy = 1.00000
# Iter 327680,Minibatch Loss = 0.005082, Training Accuracy = 1.00000
# Iter 328960,Minibatch Loss = 0.011452, Training Accuracy = 1.00000
# Iter 330240,Minibatch Loss = 0.021945, Training Accuracy = 0.98438
# Iter 331520,Minibatch Loss = 0.008822, Training Accuracy = 1.00000
# Iter 332800,Minibatch Loss = 0.037957, Training Accuracy = 0.98438
# Iter 334080,Minibatch Loss = 0.011080, Training Accuracy = 1.00000
# Iter 335360,Minibatch Loss = 0.005954, Training Accuracy = 1.00000
# Iter 336640,Minibatch Loss = 0.033830, Training Accuracy = 0.99219
# Iter 337920,Minibatch Loss = 0.024350, Training Accuracy = 0.99219
# Iter 339200,Minibatch Loss = 0.017934, Training Accuracy = 0.99219
# Iter 340480,Minibatch Loss = 0.035718, Training Accuracy = 0.98438
# Iter 341760,Minibatch Loss = 0.042033, Training Accuracy = 0.99219
# Iter 343040,Minibatch Loss = 0.032423, Training Accuracy = 0.99219
# Iter 344320,Minibatch Loss = 0.016853, Training Accuracy = 0.99219
# Iter 345600,Minibatch Loss = 0.006481, Training Accuracy = 1.00000
# Iter 346880,Minibatch Loss = 0.084088, Training Accuracy = 0.98438
# Iter 348160,Minibatch Loss = 0.023733, Training Accuracy = 1.00000
# Iter 349440,Minibatch Loss = 0.025479, Training Accuracy = 0.99219
# Iter 350720,Minibatch Loss = 0.015343, Training Accuracy = 1.00000
# Iter 352000,Minibatch Loss = 0.069648, Training Accuracy = 0.97656
# Iter 353280,Minibatch Loss = 0.028395, Training Accuracy = 0.98438
# Iter 354560,Minibatch Loss = 0.035306, Training Accuracy = 0.99219
# Iter 355840,Minibatch Loss = 0.074106, Training Accuracy = 0.97656
# Iter 357120,Minibatch Loss = 0.009295, Training Accuracy = 1.00000
# Iter 358400,Minibatch Loss = 0.030216, Training Accuracy = 0.98438
# Iter 359680,Minibatch Loss = 0.031310, Training Accuracy = 0.98438
# Iter 360960,Minibatch Loss = 0.006071, Training Accuracy = 1.00000
# Iter 362240,Minibatch Loss = 0.011819, Training Accuracy = 0.99219
# Iter 363520,Minibatch Loss = 0.011737, Training Accuracy = 1.00000
# Iter 364800,Minibatch Loss = 0.004041, Training Accuracy = 1.00000
# Iter 366080,Minibatch Loss = 0.043874, Training Accuracy = 0.98438
# Iter 367360,Minibatch Loss = 0.005612, Training Accuracy = 1.00000
# Iter 368640,Minibatch Loss = 0.004762, Training Accuracy = 1.00000
# Iter 369920,Minibatch Loss = 0.014710, Training Accuracy = 1.00000
# Iter 371200,Minibatch Loss = 0.070873, Training Accuracy = 0.97656
# Iter 372480,Minibatch Loss = 0.036071, Training Accuracy = 0.99219
# Iter 373760,Minibatch Loss = 0.023311, Training Accuracy = 0.99219
# Iter 375040,Minibatch Loss = 0.015166, Training Accuracy = 0.99219
# Iter 376320,Minibatch Loss = 0.040767, Training Accuracy = 0.97656
# Iter 377600,Minibatch Loss = 0.005613, Training Accuracy = 1.00000
# Iter 378880,Minibatch Loss = 0.011718, Training Accuracy = 1.00000
# Iter 380160,Minibatch Loss = 0.021268, Training Accuracy = 0.99219
# Iter 381440,Minibatch Loss = 0.014334, Training Accuracy = 1.00000
# Iter 382720,Minibatch Loss = 0.025499, Training Accuracy = 0.99219
# Iter 384000,Minibatch Loss = 0.017229, Training Accuracy = 1.00000
# Iter 385280,Minibatch Loss = 0.007717, Training Accuracy = 1.00000
# Iter 386560,Minibatch Loss = 0.037946, Training Accuracy = 0.98438
# Iter 387840,Minibatch Loss = 0.022080, Training Accuracy = 0.99219
# Iter 389120,Minibatch Loss = 0.007702, Training Accuracy = 1.00000
# Iter 390400,Minibatch Loss = 0.006020, Training Accuracy = 1.00000
# Iter 391680,Minibatch Loss = 0.021702, Training Accuracy = 0.99219
# Iter 392960,Minibatch Loss = 0.008708, Training Accuracy = 1.00000
# Iter 394240,Minibatch Loss = 0.031040, Training Accuracy = 0.99219
# Iter 395520,Minibatch Loss = 0.046340, Training Accuracy = 0.99219
# Iter 396800,Minibatch Loss = 0.057537, Training Accuracy = 0.99219
# Iter 398080,Minibatch Loss = 0.066904, Training Accuracy = 0.97656
# Iter 399360,Minibatch Loss = 0.050806, Training Accuracy = 0.99219
# Optimization Finished

# %%
ord(u'我')
# Out:
# 25105

# %%
print unichr(0x9FD5)
# Out:
# 鿕
